# %%
import os
import pandas as pd
import numpy as np

# %%
# set working directory
os.chdir("/Edwisor/Python")

# %%
# Loading the tarin and test file
bd_train=pd.read_csv("/Users/subhadeep/Downloads/train (1).csv")
bd_test=pd.read_csv("/Users/subhadeep/Downloads/test (1).csv")

# %%
# looking at the shape of the data
print(bd_train.shape)
print(bd_test.shape)
# Out:
# (200000, 202)
# (200000, 201)

# %%
bd_train.head(5)
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7   ...     var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266   ...      4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338   ...      7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155   ...      2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250   ...      4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514   ...     -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# ...

# %%
bd_test.head(5)
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8   ...     var_190  var_191  var_192  var_193  var_194  \
# 0  18.2675  2.1337   ...     -2.1556  11.8495  -1.4300   2.4508  13.7112
# 1  18.6316 -4.4131   ...     10.6165   8.8349   0.9403  10.1282  15.5765
# 2  20.2537  1.5233   ...     -0.7484  10.9935   1.9803   2.1800  12.9813
# 3  20.5660  3.3755   ...      9.5702   9.0766   1.6580   3.5813  15.1874
# 4  10.6048  2.9890   ...      4.2259   9.1723   1.2835   3.3778  19.5542
#
#    var_195  var_196  var_197  var_198  var_199
# 0   2.4669   4.3654  10.7200  15.4722  -8.7197
# ...

# %%
# just to set the display upto 500 rowwise and column wise 
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
# This is numeric dataset except the ID_code
bd_train.dtypes
# Out:
# ID_code     object
# target       int64
# var_0      float64
# var_1      float64
# var_2      float64
# var_3      float64
# var_4      float64
# var_5      float64
# var_6      float64
# var_7      float64
# var_8      float64
# var_9      float64
# var_10     float64
# var_11     float64
# var_12     float64
# var_13     float64
# var_14     float64
# var_15     float64
# var_16     float64
# var_17     float64
# var_18     float64
# var_19     float64
# var_20     float64
# var_21     float64
# var_22     float64
# var_23     float64
# var_24     float64
# var_25     float64
# var_26     float64
# var_27     float64
# var_28     float64
# var_29     float64
# var_30     float64
# var_31     float64
# var_32     float64
# var_33     float64
# var_34     float64
# var_35     float64
# var_36     float64
# var_37     float64
# var_38     float64
# var_39     float64
# var_40     float64
# var_41     float64
# var_42     float64
# var_43     float64
# var_44     float64
# ...

# %%
bd_test.dtypes
# Out:
# ID_code     object
# var_0      float64
# var_1      float64
# var_2      float64
# var_3      float64
# var_4      float64
# var_5      float64
# var_6      float64
# var_7      float64
# var_8      float64
# var_9      float64
# var_10     float64
# var_11     float64
# var_12     float64
# var_13     float64
# var_14     float64
# var_15     float64
# var_16     float64
# var_17     float64
# var_18     float64
# var_19     float64
# var_20     float64
# var_21     float64
# var_22     float64
# var_23     float64
# var_24     float64
# var_25     float64
# var_26     float64
# var_27     float64
# var_28     float64
# var_29     float64
# var_30     float64
# var_31     float64
# var_32     float64
# var_33     float64
# var_34     float64
# var_35     float64
# var_36     float64
# var_37     float64
# var_38     float64
# var_39     float64
# var_40     float64
# var_41     float64
# var_42     float64
# var_43     float64
# var_44     float64
# var_45     float64
# ...

# %% [markdown]
# ## Let us look into ditribution of the Training Data and Test Data

# %%
bd_train_new=bd_train.drop(['target','ID_code'],axis=1)

# %%
print(bd_train_new.shape)
# Out:
# (200000, 200)

# %%
x=bd_train_new
y=bd_train['target']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Selecting the first 100 columns
x_100=x.iloc[:,:100]

# %%
# Selecting columns from 100 to 200
x_200=x.iloc[:,100:200]

# %%
# histogram plots
# %matplotlib inline
x_100.hist(figsize=(20,20),bins=100)
plt.show()

# %%
# %matplotlib inline
x_200.hist(figsize=(20,20),bins=100)
plt.show()

# %%
# selecting forst 100 variables from the test data
bd_test_100=bd_test.iloc[:,:100]

# %%
# selecting 100 to 200 varibles from the test data
bd_test_200=bd_test.iloc[:,100:200]

# %%
# %matplotlib inline
bd_test_100.hist(figsize=(20,20),bins=100)
plt.show()

# %%
# %matplotlib inline
bd_test_200.hist(figsize=(20,20),bins=100)
plt.show()

# %% [markdown]
# ## Missing Value Analysis

# %%
# we have copied the master trainibg data for future purpose
df=x.copy()

# %%
# No missing value in training dataset
bd_train.isnull().sum()
# Out:
# ID_code    0
# target     0
# var_0      0
# var_1      0
# var_2      0
# var_3      0
# var_4      0
# var_5      0
# var_6      0
# var_7      0
# var_8      0
# var_9      0
# var_10     0
# var_11     0
# var_12     0
# var_13     0
# var_14     0
# var_15     0
# var_16     0
# var_17     0
# var_18     0
# var_19     0
# var_20     0
# var_21     0
# var_22     0
# var_23     0
# var_24     0
# var_25     0
# var_26     0
# var_27     0
# var_28     0
# var_29     0
# var_30     0
# var_31     0
# var_32     0
# var_33     0
# var_34     0
# var_35     0
# var_36     0
# var_37     0
# var_38     0
# var_39     0
# var_40     0
# var_41     0
# var_42     0
# var_43     0
# var_44     0
# var_45     0
# var_46     0
# var_47     0
# var_48     0
# var_49     0
# var_50     0
# var_51     0
# var_52     0
# var_53     0
# var_54     0
# var_55     0
# var_56     0
# var_57     0
# var_58     0
# var_59     0
# var_60     0
# var_61     0
# var_62     0
# var_63     0
# ...

# %%
# # No missing value in testing dataset
bd_test.isnull().sum()
# Out:
# ID_code    0
# var_0      0
# var_1      0
# var_2      0
# var_3      0
# var_4      0
# var_5      0
# var_6      0
# var_7      0
# var_8      0
# var_9      0
# var_10     0
# var_11     0
# var_12     0
# var_13     0
# var_14     0
# var_15     0
# var_16     0
# var_17     0
# var_18     0
# var_19     0
# var_20     0
# var_21     0
# var_22     0
# var_23     0
# var_24     0
# var_25     0
# var_26     0
# var_27     0
# var_28     0
# var_29     0
# var_30     0
# var_31     0
# var_32     0
# var_33     0
# var_34     0
# var_35     0
# var_36     0
# var_37     0
# var_38     0
# var_39     0
# var_40     0
# var_41     0
# var_42     0
# var_43     0
# var_44     0
# var_45     0
# var_46     0
# var_47     0
# var_48     0
# var_49     0
# var_50     0
# var_51     0
# var_52     0
# var_53     0
# var_54     0
# var_55     0
# var_56     0
# var_57     0
# var_58     0
# var_59     0
# var_60     0
# var_61     0
# var_62     0
# var_63     0
# var_64     0
# ...

# %%
# Summary of the dataset
x.describe()
# Out:
#                var_0          var_1          var_2          var_3  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       10.679914      -1.627622      10.715192       6.796529
# std         3.040051       4.050044       2.640894       2.043319
# min         0.408400     -15.043400       2.117100      -0.040200
# 25%         8.453850      -4.740025       8.722475       5.254075
# 50%        10.524750      -1.608050      10.580000       6.825000
# 75%        12.758200       1.358625      12.516700       8.324100
# max        20.315000      10.376800      19.353000      13.188300
#
#                var_4          var_5          var_6          var_7  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       11.078333      -5.065317       5.408949      16.545850
# std         1.623150       7.863267       0.866607       3.418076
# min         5.074800     -32.562600       2.347300       5.349700
# ...

# %% [markdown]
# # Feature Selection

# %%
## set the width and height of the plot
# subplot will decide the height and width of the plot
f, ax = plt.subplots(figsize=(7,5))

# generating correlation matrix
corr=x.corr()

## mask will crate individual blocks in correlation matrix, np.zeroes will create square blocks in whole paine
##cmap. diverse_palette will set the colours
## plot using seaborn libraray
sns.heatmap(corr, mask=np.zeros_like(corr,dtype=np.bool),cmap=sns.diverging_palette(220,10,as_cmap=True),
           square= True,ax=ax)

# %% [markdown]
# ##Take away from the correlation plot is that there is hardly any correlation between the independent variables.

# %%
f, ax = plt.subplots(figsize=(7,5))
corr1=bd_test.corr()
sns.heatmap(corr1, mask=np.zeros_like(corr1,dtype=np.bool),cmap=sns.diverging_palette(220,10,as_cmap=True),
           square= True,ax=ax)

# %%
from sklearn.ensemble import (RandomForestClassifier)

# %%
# makinga baseline random forest for feature importance
clf_rf = RandomForestClassifier(n_estimators=100,max_features=30,n_jobs=-1)

# %%
clf_rf.fit(x,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=30, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
# feature importance
feature_imp = pd.Series(clf_rf.feature_importances_,index=x.columns).sort_values(ascending=False)
feature_imp
# Out:
# var_81     0.013597
# var_139    0.010694
# var_12     0.010508
# var_53     0.009588
# var_110    0.009222
# var_26     0.009053
# var_174    0.008790
# var_146    0.008484
# var_22     0.008353
# var_166    0.008302
# var_109    0.008273
# var_80     0.008223
# var_6      0.007891
# var_76     0.007816
# var_99     0.007338
# var_165    0.007268
# var_78     0.007221
# var_198    0.007145
# var_179    0.007141
# var_133    0.007060
# var_13     0.007019
# var_2      0.006939
# var_1      0.006904
# var_148    0.006835
# var_44     0.006820
# var_164    0.006817
# var_190    0.006796
# var_0      0.006795
# var_40     0.006654
# var_170    0.006609
# var_34     0.006601
# var_33     0.006555
# var_21     0.006481
# var_94     0.006448
# var_9      0.006269
# var_154    0.006211
# var_108    0.006200
# var_191    0.006104
# var_184    0.006089
# var_177    0.006087
# var_92     0.006031
# var_18     0.005920
# var_121    0.005890
# var_115    0.005888
# var_91     0.005564
# ...

# %%
# %matplotlib inline
# Creating a bar plot
f, ax = plt.subplots(figsize=(25,35))
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to the graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
#plt.legend()
plt.show()

# %% [markdown]
# ## Outlier Analysis

# %%
# plot boxplot to visualize
# %matplotlib inline

# %%
plt.boxplot(x['var_0'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x116258978>],
#  'caps': [<matplotlib.lines.Line2D at 0x11e8203c8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x11e84b080>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11e820c18>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x116258ac8>,
#   <matplotlib.lines.Line2D at 0x116258f60>]}

# %%
plt.boxplot(x['var_1'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x11624bcf8>],
#  'caps': [<matplotlib.lines.Line2D at 0x11e8d9748>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x11e8ec400>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11e8d9f98>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11624be48>,
#   <matplotlib.lines.Line2D at 0x11e8d9320>]}

# %%
cnames=x.columns

# %%
cnames
# Out:
# Index(['var_0', 'var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'var_6', 'var_7',
#        'var_8', 'var_9',
#        ...
#        'var_190', 'var_191', 'var_192', 'var_193', 'var_194', 'var_195',
#        'var_196', 'var_197', 'var_198', 'var_199'],
#       dtype='object', length=200)

# %%
# detect and replace  outliers with NAN  from the training data 
for i in cnames:
    print(i)
    q75, q25 =np.percentile(x.loc[:,i],[75,25])
    iqr= q75-q25
    
    min= q25-(iqr*1.5)
    max= q75+ (iqr*1.5)
    
    print(min)
    print(max)
    
    ## replacing with NAs
    x.loc[x[i]< min,:i]=np.nan
    x.loc[x[i]> max,:i]=np.nan
# Out:
# var_0
# 1.9973250000000018
# 19.214725
# var_1
# -13.888000000000002
# 10.5066
# var_2
# 3.031137499999998
# 18.208037500000003
# var_3
# 0.6490375000000013
# 12.9291375
# var_4
# 6.316249999999997
# 15.828050000000005
# var_5
# -29.388075
# 19.112525
# var_6
# 2.91475
# 7.855949999999998
# var_7
# 6.205149999999996
# 26.841550000000005
# var_8
# -10.20135
# 10.821449999999999
# var_9
# 3.6703625000000013
# 11.532862499999998
# var_10
# -15.561762500000002
# 16.349737500000003
# var_11
# -20.0557375
# 13.397962499999998
# var_12
# 13.488700000000001
# 14.569499999999998
# var_13
# -5.7301625
# 23.077737499999998
# var_14
# 0.549050000000002
# 14.503249999999998
# var_15
# 13.345250000000002
# 15.792049999999998
# var_16
# 2.0468375000000014
# 16.4613375
# var_17
# -24.974400000000003
# 13.687400000000004
# var_18
# -8.575112500000007
# 38.76638750000001
# var_19
# -11.958762499999995
# 36.6685375
# var_20
# -5.249599999999999
# 31.7568
# var_21
# -5.75607500000001
# ...

# %%
## Caluclate missing value
missing_val=pd.DataFrame(x.isnull().sum())

# %%
missing_val
# Out:
#              0
# var_0    24896
# var_1    24804
# var_2    24798
# var_3    24761
# var_4    24743
# var_5    24677
# var_6    24673
# var_7    24573
# var_8    24556
# var_9    24554
# var_10   24554
# var_11   24444
# var_12   24163
# var_13   24129
# var_14   24129
# var_15   24127
# var_16   24108
# var_17   24051
# var_18   23855
# var_19   23846
# var_20   23845
# var_21   23844
# var_22   23596
# var_23   23330
# var_24   23251
# var_25   23247
# var_26   23030
# var_27   22865
# var_28   22862
# var_29   22693
# var_30   22563
# var_31   22552
# var_32   21992
# var_33   21990
# var_34   21987
# var_35   21979
# var_36   21794
# var_37   21632
# var_38   21631
# var_39   21187
# var_40   21047
# var_41   21003
# var_42   21003
# var_43   20973
# var_44   20958
# var_45   19860
# var_46   19820
# var_47   19577
# var_48   19575
# var_49   19490
# var_50   19485
# var_51   19283
# var_52   19246
# var_53   18935
# var_54   18910
# var_55   18873
# var_56   18873
# ...

# %%
## impute with mean
x_new=x.apply(lambda x: x.fillna(x.mean()),axis=0)

# %%
x_new.isnull().sum()
# Out:
# var_0      0
# var_1      0
# var_2      0
# var_3      0
# var_4      0
# var_5      0
# var_6      0
# var_7      0
# var_8      0
# var_9      0
# var_10     0
# var_11     0
# var_12     0
# var_13     0
# var_14     0
# var_15     0
# var_16     0
# var_17     0
# var_18     0
# var_19     0
# var_20     0
# var_21     0
# var_22     0
# var_23     0
# var_24     0
# var_25     0
# var_26     0
# var_27     0
# var_28     0
# var_29     0
# var_30     0
# var_31     0
# var_32     0
# var_33     0
# var_34     0
# var_35     0
# var_36     0
# var_37     0
# var_38     0
# var_39     0
# var_40     0
# var_41     0
# var_42     0
# var_43     0
# var_44     0
# var_45     0
# var_46     0
# var_47     0
# var_48     0
# var_49     0
# var_50     0
# var_51     0
# var_52     0
# var_53     0
# var_54     0
# var_55     0
# var_56     0
# var_57     0
# var_58     0
# var_59     0
# var_60     0
# var_61     0
# var_62     0
# var_63     0
# var_64     0
# var_65     0
# ...

# %%
x_new.describe()
# Out:
#                var_0          var_1          var_2          var_3  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       10.680009      -1.636018      10.711579       6.795464
# std         2.836903       3.789421       2.466563       1.912184
# min         2.004400     -13.867400       3.035500       0.673200
# 25%         8.763800      -4.268400       8.987000       5.483800
# 50%        10.680009      -1.636018      10.711579       6.795464
# 75%        12.434650       0.908325      12.278800       8.106100
# max        19.213500      10.376800      18.206700      12.924900
#
#                var_4          var_5          var_6          var_7  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       11.078619      -5.070598       5.407901      16.545879
# std         1.516982       7.366005       0.809304       3.200692
# min         6.318300     -29.188300       2.917000       6.465300
# ...

# %%
x_new.shape
# Out:
# (200000, 200)

# %% [markdown]
# ## Feature scalling

# %%
df1=x_new.copy()

# %%
# normality check
# %matplotlib inline
x_new['var_0'].hist(bins=100)

# %%
x_new['var_20'].hist(bins=100)

# %%
## if we see every varibles in histogram we will se that all the varibles are not in normalization.
# hence will go for normalization instead of standarization.
##NORMALIZATION
for i in cnames:
    print(i)
    x_new[i]= (x_new[i] - np.min(x_new[i]))/(np.max(x_new[i]) - np.min(x_new[i]))
# Out:
# var_0
# var_1
# var_2
# var_3
# var_4
# var_5
# var_6
# var_7
# var_8
# var_9
# var_10
# var_11
# var_12
# var_13
# var_14
# var_15
# var_16
# var_17
# var_18
# var_19
# var_20
# var_21
# var_22
# var_23
# var_24
# var_25
# var_26
# var_27
# var_28
# var_29
# var_30
# var_31
# var_32
# var_33
# var_34
# var_35
# var_36
# var_37
# var_38
# var_39
# var_40
# var_41
# var_42
# var_43
# var_44
# var_45
# var_46
# var_47
# var_48
# var_49
# var_50
# var_51
# var_52
# var_53
# var_54
# var_55
# var_56
# var_57
# var_58
# var_59
# var_60
# var_61
# var_62
# var_63
# var_64
# var_65
# var_66
# var_67
# var_68
# var_69
# var_70
# var_71
# var_72
# var_73
# var_74
# var_75
# var_76
# var_77
# var_78
# var_79
# var_80
# var_81
# var_82
# var_83
# var_84
# var_85
# var_86
# var_87
# var_88
# var_89
# var_90
# var_91
# var_92
# var_93
# var_94
# var_95
# var_96
# var_97
# var_98
# var_99
# var_100
# var_101
# var_102
# var_103
# var_104
# var_105
# var_106
# var_107
# var_108
# var_109
# var_110
# ...

# %%
# %matplotlib inline
x_new['var_0'].hist(bins=100)

# %%
x_new.head(10)
# Out:
#       var_0     var_1     var_2     var_3     var_4     var_5     var_6  \
# 0  0.402177  0.292074  0.584832  0.360750  0.541944  0.428616  0.445950
# 1  0.504129  0.504508  0.505964  0.499707  0.501678  0.519331  0.504527
# 2  0.383803  0.458737  0.596195  0.589273  0.449393  0.432917  0.815398
# 3  0.526233  0.483233  0.389996  0.532375  0.660389  0.588981  0.592615
# 4  0.455137  0.510803  0.648538  0.486814  0.627993  0.681244  0.612404
# 5  0.550401  0.476370  0.630965  0.649151  0.489398  0.705195  0.327156
# 6  0.569739  0.568557  0.416177  0.295339  0.507672  0.455826  0.664175
# 7  0.671366  0.242503  0.714650  0.565252  0.246185  0.646412  0.561463
# 8  0.819491  0.672738  0.718150  0.404801  0.261687  0.761227  0.310790
# 9  0.610398  0.653422  0.386291  0.389954  0.767853  0.277830  0.637358
#
#       var_7     var_8     var_9    var_10    var_11    var_12    var_13  \
# 0  0.596853  0.251762  0.247420  0.582088  0.694649  0.484443  0.204591
# ...

# %% [markdown]
# ## Imbalanced Dataset Handling

# %%
#target classes count
target_class=y.value_counts()

print('Count of target classes :\n',target_class)
#Percentage of target classes count
per_target_class=y.value_counts()/len(bd_train_new)*100
                                      
print('percentage of count of target classes :\n',per_target_class)
# Out:
# Count of target classes :
#  0    179902
# 1     20098
# Name: target, dtype: int64
# percentage of count of target classes :
#  0    89.951
# 1    10.049
# Name: target, dtype: float64

# %% [markdown]
# So we can see that the target class is imbalanced.

# %% [markdown]
# ## MODEL DEVELOPMENT

# %%
from sklearn.model_selection import KFold,train_test_split

# %%
# split the data, 75% into tarin and 25% into test data
x1_train,x1_test,y1_train,y1_test=train_test_split(x_new,y,test_size=0.25,random_state=2)

# %%
print (x1_train.shape,y1_train.shape)
print (x1_test.shape,y1_test.shape)
# Out:
# (150000, 200) (150000,)
# (50000, 200) (50000,)

# %%
x1_train.reset_index(drop=True, inplace=True)
y1_train.reset_index(drop=True, inplace=True)

# %%
from sklearn.linear_model import LogisticRegression

# %%
# buildinga logistic regression model
lr1=LogisticRegression(class_weight='balanced')

# %%
lr1.fit(x1_train,y1_train)
# Out:
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predicted_lr1=lr1.predict(x1_test)

# %%
from sklearn.metrics import roc_auc_score,confusion_matrix,roc_curve
from sklearn import metrics
from sklearn.metrics import classification_report

# %%
# calculating roc_auc_score
roc_auc_score(y1_test,predicted_lr1)
# Out:
# 0.7593689713025209

# %%
print("Accuracy:",metrics.accuracy_score(y1_test, predicted_lr1))
print("Precision:",metrics.precision_score(y1_test, predicted_lr1))
print("Recall:",metrics.recall_score(y1_test, predicted_lr1))
# Out:
# Accuracy: 0.76782
# Precision: 0.2714114241333051
# Recall: 0.748733930658356

# %%
scores1=classification_report(y1_test,predicted_lr1)
print(scores1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.77      0.86     44866
#            1       0.27      0.75      0.40      5134
#
#     accuracy                           0.77     50000
#    macro avg       0.62      0.76      0.63     50000
# weighted avg       0.89      0.77      0.81     50000

# %%
y_pred_proba = lr1.predict_proba(x1_test)[:,1]
fpr, tpr, _ = metrics.roc_curve(y1_test,y_pred_proba)
auc = metrics.roc_auc_score(y1_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## Logistic Regression with startified distribution

# %%
# spliting the data into train and test with stratified sampling
x_train,x_test,y_train,y_test=train_test_split(x_new,y,test_size=0.25,random_state=2,stratify=y)

# %%
print (x_train.shape,y_train.shape)
print (x_test.shape,y_test.shape)
# Out:
# (150000, 200) (150000,)
# (50000, 200) (50000,)

# %%
y_train.value_counts()
# Out:
# 0    134926
# 1     15074
# Name: target, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    44976
# 1     5024
# Name: target, dtype: int64

# %%
x_train.index
# Out:
# Int64Index([ 18623,  37693, 169284,  40009, 109265,  52644,  40592,  96143,
#              61894,  85298,
#             ...
#              61920, 143314,  25962,  56051,  85653, 122772, 147445, 169066,
#             150100,  43683],
#            dtype='int64', length=150000)

# %%
x_train.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)

# %%
x_train.index
# Out:
# RangeIndex(start=0, stop=150000, step=1)

# %%
lr=LogisticRegression(class_weight='balanced')

# %%
lr.fit(x_train,y_train)
# Out:
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predicted_lr=lr.predict(x_test)

# %%
roc_auc_score(y_test,predicted_lr)
# Out:
# 0.7607464603910479

# %%
conf_mat=confusion_matrix(y_test,predicted_lr)

# %%
conf_mat
# Out:
# array([[34636, 10340],
#        [ 1249,  3775]])

# %%
conf_mat_crosstab=pd.crosstab(y_test,predicted_lr)

# %%
conf_mat_crosstab
# Out:
# col_0       0      1
# target
# 0       34636  10340
# 1        1249   3775

# %%
print("Accuracy:",metrics.accuracy_score(y_test, predicted_lr))
print("Precision:",metrics.precision_score(y_test, predicted_lr))
print("Recall:",metrics.recall_score(y_test, predicted_lr))
print("F1Score:",metrics.f1_score(y_test,predicted_lr))
# Out:
# Accuracy: 0.76822
# Precision: 0.26744597945448106
# Recall: 0.7513933121019108
# F1Score: 0.3944824703485031

# %%
scores=classification_report(y_test,predicted_lr)

# %%
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.77      0.86     44976
#            1       0.27      0.75      0.39      5024
#
#     accuracy                           0.77     50000
#    macro avg       0.62      0.76      0.63     50000
# weighted avg       0.90      0.77      0.81     50000

# %%
y_pred_stra_proba = lr.predict_proba(x_test)[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test,y_pred_stra_proba)
auc = metrics.roc_auc_score(y_test, y_pred_stra_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from imblearn.over_sampling import SMOTE

# %%
# building a logistic regression model with the help of SMOTE.

print("Before OverSampling, counts of label '1': {}".format(sum(y==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y==0)))

sm = SMOTE(random_state=2,ratio=1.0)
X_train_sm, y_train_sm = sm.fit_sample(x_train, y_train)

print('After OverSampling, the shape of train_X: {}'.format(X_train_sm.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_sm.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_sm==1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_sm==0)))
# Out:
# Before OverSampling, counts of label '1': 20098
# Before OverSampling, counts of label '0': 179902
#
# After OverSampling, the shape of train_X: (269852, 200)
# After OverSampling, the shape of train_y: (269852,)
#
# After OverSampling, counts of label '1': 134926
# After OverSampling, counts of label '0': 134926

# %%
lr_sm=LogisticRegression(class_weight='balanced',random_state=2)

# %%
lr_sm.fit(X_train_sm,y_train_sm)
# Out:
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=2, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predicted_lr_sm=lr_sm.predict(x_test)

# %%
roc_auc_score(y_test,predicted_lr_sm)
# Out:
# 0.7483657950907151

# %%
conf_mat_sm=confusion_matrix(y_test,predicted_lr_sm)

# %%
conf_mat_sm
# Out:
# array([[30774, 14202],
#        [  942,  4082]])

# %%
conf_mat_sm_crosstab=pd.crosstab(y_test,predicted_lr_sm)

# %%
conf_mat_sm_crosstab
# Out:
# col_0       0      1
# target
# 0       30774  14202
# 1         942   4082

# %%
print("Accuracy:",metrics.accuracy_score(y_test, predicted_lr_sm))
print("Precision:",metrics.precision_score(y_test, predicted_lr_sm))
print("Recall:",metrics.recall_score(y_test, predicted_lr_sm))
# Out:
# Accuracy: 0.69712
# Precision: 0.22325530518486109
# Recall: 0.8125

# %%
scores_sm=classification_report(y_test,predicted_lr_sm)

# %%
print(scores_sm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.68      0.80     44976
#            1       0.22      0.81      0.35      5024
#
#     accuracy                           0.70     50000
#    macro avg       0.60      0.75      0.58     50000
# weighted avg       0.90      0.70      0.76     50000

# %%
y_pred_sm_proba = lr_sm.predict_proba(x_test)[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test,y_pred_sm_proba)
auc = metrics.roc_auc_score(y_test, y_pred_sm_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# building a roandom forest classifier 
clf_rf=RandomForestClassifier(verbose=1,n_jobs=-1,)

# %%
# making a param)dist , a dictonary for hyperparameter tuning.
param_dist = {"n_estimators":[10,50,100,200],
              "max_depth": [3,5,10, None],
              "max_features": [5,10,20],
              "min_samples_split": [2,5,10],
              "min_samples_leaf": [1,5,10],
              "criterion": ["gini", "entropy"]}

n_iter_search = 20

# %%
# making a randomizedsearCV for best possible combination parameter. here we are doing 10 fold cross validation
# with 20 times . scoring methid will be based on roc_auc
random_search = RandomizedSearchCV(clf_rf, param_distributions=param_dist,
                                   n_iter=n_iter_search,scoring='roc_auc',cv=10)
random_search.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  3.9min finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  3.9min finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# ...

# %%
print(random_search.best_score_)
print(random_search.best_params_)
print(random_search.best_estimator_)
# Out:
# 0.8489810827147368
# {'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 5, 'max_depth': None, 'criterion': 'gini'}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=5, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=10, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=None, verbose=1,
#                        warm_start=False)

# %%
# building a randomforestclassifier for best possible parameter.
rf=RandomForestClassifier(n_estimators=200,min_samples_split=10,min_samples_leaf=10,max_features=5,max_depth=None,
                         criterion='gini',bootstrap=True,random_state=2,n_jobs=-1,class_weight="balanced")

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#                        criterion='gini', max_depth=None, max_features=5,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=10,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        n_estimators=200, n_jobs=-1, oob_score=False,
#                        random_state=2, verbose=0, warm_start=False)

# %%
predicted_rf=rf.predict(x_test)

# %%
roc_auc_score(y_test,predicted_rf)
# Out:
# 0.5052338246357009

# %%
conf_rf=confusion_matrix(y_test,predicted_rf)

# %%
conf_rf
# Out:
# array([[44471,   505],
#        [ 4915,   109]])

# %%
conf_rf_crosstab=pd.crosstab(y_test,predicted_rf)

# %%
conf_rf_crosstab
# Out:
# col_0       0    1
# target
# 0       44471  505
# 1        4915  109

# %%
print("Accuracy:",metrics.accuracy_score(y_test, predicted_rf))
print("Precision:",metrics.precision_score(y_test, predicted_rf))
print("Recall:",metrics.recall_score(y_test, predicted_rf))
# Out:
# Accuracy: 0.8916
# Precision: 0.1775244299674267
# Recall: 0.021695859872611464

# %%
scores_rf=classification_report(y_test,predicted_rf)
print(scores_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94     44976
#            1       0.18      0.02      0.04      5024
#
#     accuracy                           0.89     50000
#    macro avg       0.54      0.51      0.49     50000
# weighted avg       0.83      0.89      0.85     50000

# %%
y_pred_rf = rf.predict_proba(x_test)[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test,y_pred_rf)
auc = metrics.roc_auc_score(y_test, y_pred_rf)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import StratifiedKFold

# %%
# building a baseline xgbclassifier model
baseline_xgb = XGBClassifier(learning_rate=0.1, n_estimators=100,max_depth=3,
                             subsample=1,random_state=2,scale_pos_weight=9)

# %%
baseline_xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               max_features='sqrt', min_child_weight=1, min_samples_leaf=1,
#               min_samples_split=2, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=2,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=9, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
predicted_baseline_xgb=baseline_xgb.predict(x_test)

# %%
roc_auc_score(y_test,predicted_baseline_xgb)
# Out:
# 0.741927364799797

# %%
con_baseline_xgb=confusion_matrix(y_test,predicted_baseline_xgb)

# %%
con_baseline_xgb
# Out:
# array([[35414,  9562],
#        [ 1525,  3499]])

# %%
print("Accuracy:",metrics.accuracy_score(y_test, predicted_baseline_xgb))
print("Precision:",metrics.precision_score(y_test, predicted_baseline_xgb))
print("Recall:",metrics.recall_score(y_test, predicted_baseline_xgb))
# Out:
# Accuracy: 0.77826
# Precision: 0.2678967919761121
# Recall: 0.6964570063694268

# %%
xgb1=XGBClassifier(njobs=-1,scale_pos_weight=9)

# %%
# hyperparameter tuning set for param_dist
param_dist1 = {"learning_rate":[0.05,0.1,0.2], 
               "n_estimators":[100,150,250],
               "max_depth": [3,4,5],
               "subsample":[0.8,1,0.5],
               "colsample_bytree":[0.6,0.7,0.8]
              }
n_iter_search=20
cv_strat=StratifiedKFold(n_splits=10,shuffle=True,random_state=2)

# %%
# hyperparameter tuning for xgbooost 
random_search = RandomizedSearchCV(xgb1, param_distributions=param_dist1,
                                   n_iter=n_iter_search,scoring='roc_auc',cv=cv_strat)
random_search.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=10, random_state=2, shuffle=True),
#                    error_score='raise-deprecating',
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1, gamma=0,
#                                            learning_rate=0.1, max_delta_step=0,
#                                            max_depth=3, min_child_weight=1,
#                                            missing=None, n_estimators=100,
#                                            n_jobs=1, njobs=-1, nth...
#                                            reg_lambda=1, scale_pos_weight=9,
#                                            seed=None, silent=None, subsample=1,
#                                            verbosity=1),
# ...

# %%
print(random_search.best_score_)
print(random_search.best_params_)
print(random_search.best_estimator_)
# Out:
# 0.8668797450201314
# {'subsample': 0.5, 'n_estimators': 250, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.7}
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.7, gamma=0,
#               learning_rate=0.2, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=250, n_jobs=1,
#               njobs=-1, nthread=None, objective='binary:logistic',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=9,
#               seed=None, silent=None, subsample=0.5, verbosity=1)

# %%
# algorithm with bast combination of parameter set after doing hyperparameter tuning. also we have taken scale_pos_weight
# as 9 because the target variable having a ratio of 9:1 of 0 and 1
xgb_random=XGBClassifier(learning_rate=0.2,n_estimators=250,max_depth=3,colsample_bytree=0.7,subsample=0.5,
                         objective='binary:logistic',scale_pos_weight=9)

# %%
xgb_random.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.7, gamma=0,
#               learning_rate=0.2, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=250, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=9, seed=None,
#               silent=None, subsample=0.5, verbosity=1)

# %%
predicted_xgb=xgb_random.predict(x_test)

# %%
roc_auc_score(y_test,predicted_xgb)
# Out:
# 0.7821823089795095

# %%
conf_xgb=confusion_matrix(y_test,predicted_xgb)

# %%
conf_xgb
# Out:
# array([[36976,  8000],
#        [ 1295,  3729]])

# %%
print("Accuracy:",metrics.accuracy_score(y_test, predicted_xgb))
print("Precision:",metrics.precision_score(y_test, predicted_xgb))
print("Recall:",metrics.recall_score(y_test, predicted_xgb))
# Out:
# Accuracy: 0.8141
# Precision: 0.3179299172990025
# Recall: 0.7422372611464968

# %%
scores_xgb=classification_report(y_test,predicted_xgb)
print(scores_xgb)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.82      0.89     44976
#            1       0.32      0.74      0.45      5024
#
#     accuracy                           0.81     50000
#    macro avg       0.64      0.78      0.67     50000
# weighted avg       0.90      0.81      0.84     50000

# %%
y_pred_xgb = xgb_random.predict_proba(x_test)[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test,y_pred_xgb)
auc = metrics.roc_auc_score(y_test, y_pred_xgb)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from vecstack import stacking
# Out:
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
# making a 1st level model for stacking with3 different baseline models which are tuned ( hyperparameter)
models = [
    LogisticRegression(class_weight='balanced'),
        
    RandomForestClassifier(n_estimators=200,min_samples_split=10,min_samples_leaf=10,max_features='sqrt',max_depth=None,
                         criterion='gini',bootstrap=True,random_state=2,n_jobs=-1,class_weight="balanced"),
        
    XGBClassifier(learning_rate=0.2,n_estimators=250,max_depth=3,colsample_bytree=0.7,subsample=0.5,
                         objective='binary:logistic',scale_pos_weight=9)
]

# %%
# creating a training and testing dataset for stacking
s_train, s_test = stacking(models,x_train,y_train,x_test,regression=False,mode='oof_pred_bag',needs_proba=False,
         save_dir=None,metric=roc_auc_score,n_folds=4,stratified=True,random_state=2,verbose=2)
# Out:
# task:         [classification]
# n_classes:    [2]
# metric:       [roc_auc_score]
# mode:         [oof_pred_bag]
# n_models:     [3]
#
# model  0:     [LogisticRegression]
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#     fold  0:  [0.75592006]
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#     fold  1:  [0.75892089]
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#     fold  2:  [0.75837934]
# ...

# %%
# taking logisticregression as 2nd level model for stacking
model=LogisticRegression(class_weight='balanced')

# %%
model.fit(s_train,y_train)
# Out:
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predict_model=model.predict(s_test)

# %%
roc_auc_score(y_test,predict_model)
# Out:
# 0.7849623833348061

# %%
conf_model=confusion_matrix(y_test,predict_model)

# %%
conf_model
# Out:
# array([[38739,  6237],
#        [ 1464,  3560]])

# %%
print("Accuracy:",metrics.accuracy_score(y_test, predict_model))
print("Precision:",metrics.precision_score(y_test, predict_model))
print("Recall:",metrics.recall_score(y_test, predict_model))
# Out:
# Accuracy: 0.84598
# Precision: 0.363376543839951
# Recall: 0.7085987261146497

# %%
scores_model=classification_report(y_test,predict_model)

# %%
print(scores_model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91     44976
#            1       0.36      0.71      0.48      5024
#
#     accuracy                           0.85     50000
#    macro avg       0.66      0.78      0.69     50000
# weighted avg       0.90      0.85      0.87     50000

# %% [markdown]
# ## developing stacking with raw data without oultier and normalisation method

# %%
bd_train.shape
# Out:
# (200000, 202)

# %%
bd_train2=bd_train.drop(['ID_code','target'],axis=1)

# %%
print(bd_train2.shape)
print(y.shape)
# Out:
# (200000, 200)
# (200000,)

# %%
# splitting the data into train and test form the original data without preprocessing
x3_train,x3_test,y3_train,y3_test=train_test_split(bd_train2,y,test_size=0.25,random_state=2,stratify=y)

# %%
print(x3_train.shape)
print(y3_train.shape)
print(x3_test.shape)
print(y3_test.shape)
# Out:
# (150000, 200)
# (150000,)
# (50000, 200)
# (50000,)

# %%
# buildinga 1st level stacking model with 3 baseline model
models = [
    LogisticRegression(class_weight='balanced'),
        
    RandomForestClassifier(n_estimators=200,min_samples_split=10,min_samples_leaf=10,max_features='sqrt',max_depth=None,
                         criterion='gini',bootstrap=True,random_state=2,n_jobs=-1,class_weight="balanced"),
        
    XGBClassifier(learning_rate=0.2,n_estimators=250,max_depth=3,colsample_bytree=0.7,subsample=0.5,
                         objective='binary:logistic',scale_pos_weight=9)
]

# %%
s2_train,s2_test=stacking(models,x3_train,y3_train,x3_test,regression=False,mode='oof_pred_bag',needs_proba=False,
         save_dir=None,metric=roc_auc_score,n_folds=4,stratified=True,random_state=2,verbose=2)
# Out:
# task:         [classification]
# n_classes:    [2]
# metric:       [roc_auc_score]
# mode:         [oof_pred_bag]
# n_models:     [3]
#
# model  0:     [LogisticRegression]
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#     fold  0:  [0.77437636]
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#     fold  1:  [0.77960353]
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#     fold  2:  [0.78296365]
# ...

# %%
# creating 2nd level model for stacking
model_new=LogisticRegression(class_weight='balanced')

# %%
model_new.fit(s2_train,y_train)
# Out:
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred_new=model_new.predict(s2_test)

# %%
roc_auc_score(y3_test,pred_new)
# Out:
# 0.8005531116949562

# %%
con=confusion_matrix(y3_test,pred_new)

# %%
print(con)
# Out:
# [[39470  5506]
#  [ 1389  3635]]

# %%
print("Accuracy:",metrics.accuracy_score(y3_test, pred_new))
print("Precision:",metrics.precision_score(y3_test, pred_new))
print("Recall:",metrics.recall_score(y3_test, pred_new))
# Out:
# Accuracy: 0.8621
# Precision: 0.3976588994639536
# Recall: 0.7235270700636943

# %%
scores_pred_new=classification_report(y3_test,pred_new)
print(scores_pred_new)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92     44976
#            1       0.40      0.72      0.51      5024
#
#     accuracy                           0.86     50000
#    macro avg       0.68      0.80      0.72     50000
# weighted avg       0.91      0.86      0.88     50000

# %%
test_data=bd_test.drop(['ID_code'],axis=1)

# %%
# now for final prediction we are creating a new data set with the entire trainig and testing data
s4_train, s4_test = stacking(models,bd_train2,y,test_data,regression=False,mode='oof_pred_bag',needs_proba=False,
         save_dir=None,metric=roc_auc_score,n_folds=4,stratified=True,random_state=2,verbose=2)
# Out:
# task:         [classification]
# n_classes:    [2]
# metric:       [roc_auc_score]
# mode:         [oof_pred_bag]
# n_models:     [3]
#
# model  0:     [LogisticRegression]
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#     fold  0:  [0.77269953]
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#     fold  1:  [0.77491192]
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#     fold  2:  [0.77884236]
# ...

# %%
# 2nd level model for stacking
raw_model=LogisticRegression(class_weight='balanced')

# %%
raw_model.fit(s4_train,y)
# Out:
# /Users/subhadeep/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
raw_predict=raw_model.predict(s4_test)

# %%
submission_new=pd.DataFrame(list(zip(bd_test['ID_code'],list(raw_predict))),
                       columns=['ID_code','target'])

# %%
submission_new.target.value_counts()
# Out:
# 0    164076
# 1     35924
# Name: target, dtype: int64

# %%
submission_new`
# Out:
#             ID_code  target
# 0            test_0       0
# 1            test_1       1
# 2            test_2       1
# 3            test_3       0
# 4            test_4       0
# 5            test_5       0
# 6            test_6       0
# 7            test_7       1
# 8            test_8       0
# 9            test_9       0
# 10          test_10       0
# 11          test_11       0
# 12          test_12       0
# 13          test_13       0
# 14          test_14       0
# 15          test_15       0
# 16          test_16       1
# 17          test_17       0
# 18          test_18       1
# 19          test_19       0
# 20          test_20       1
# 21          test_21       1
# 22          test_22       0
# 23          test_23       0
# 24          test_24       0
# 25          test_25       0
# 26          test_26       0
# 27          test_27       0
# 28          test_28       1
# 29          test_29       0
# 30          test_30       0
# 31          test_31       0
# ...
